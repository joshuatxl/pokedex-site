# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/pokedex
# Out:
# /content/drive/MyDrive/pokedex

# %%
# !cp /content/drive/MyDrive/pokedex/dataset.zip /content/
# !unzip -q /content/dataset.zip -d /content

# %%
# %cd /content/drive/MyDrive/pokedex
# Out:
# /content/drive/MyDrive/pokedex

# %%
# !python3 main.py
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100% 97.8M/97.8M [00:00<00:00, 153MB/s]
# Using device: cuda:0
#
# Start training...
# /usr/local/lib/python3.13/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# ep 1, loss: 1080.73, 10755 train 27.88%
# ep 2, loss: 520.94, 10755 train 75.30%
# ep 3, loss: 421.73, 10755 train 83.88%
# ep 4, loss: 387.20, 10755 train 87.25%
# ep 5, loss: 358.47, 10755 train 89.72%
# ep 6, loss: 345.25, 10755 train 91.19%
# ep 7, loss: 332.18, 10755 train 92.26%
# ep 8, loss: 325.88, 10755 train 92.82%
# ep 9, loss: 317.80, 10755 train 93.41%
# ep 10, loss: 310.23, 10755 train 93.95%
#    Model saved to checkModel.pth
# Figure(640x480)
#    Accuracy chart saved to accuracy_plot.png
# ...
